# %% [markdown]
# ### Ocean cleaup analysis
# ##### A program that calculates the amount of waste collected in ocean cleanup.

# %%
weekly_collection = [340, 220, 455, 300, 385, 520, 410]
total_waste_collected = 0
for daily_collection in weekly_collection:
    total_waste_collected += daily_collection
print(f"Total waste collected over the week: {total_waste_collected} kg")
# Out:
# Total waste collected over the week: 2630 kg

# %% [markdown]
# ### Monitoring endangered species
# ##### A program that tracks sightings of endangered species over a month, stopping if a certain species is spotted.

# %%
sightings = ['Deer', 'Tiger', 'Blue Whale', 'Mountain Gorilla', 'Elephant']
endangered_species = ['Tiger', 'Blue Whale', 'Mountain Gorilla']
for species in sightings:
    if species in endangered_species:
        break 
print(f"Endangered specie spotted: {species}")
# Out:
# Endangered specie spotted: Tiger

# %% [markdown]
# ### Forest growth monitoring
# ##### A program that stimulates the growth of a forest over years until it reaches a specified threshold area. The forest growth is compounded annually.

# %%
forest_area = 1000 # Initial forest area in square kilometres
growth_rate = 1.05 # 5% annual growth
year = 0
while forest_area < 5000:
    forest_area *= growth_rate
    year += 1
    print(f"Forest area after {year} years: {forest_area:.2f} sq km")
# Out:
# Forest area after 1 years: 1050.00 sq km
# Forest area after 2 years: 1102.50 sq km
# Forest area after 3 years: 1157.62 sq km
# Forest area after 4 years: 1215.51 sq km
# Forest area after 5 years: 1276.28 sq km
# Forest area after 6 years: 1340.10 sq km
# Forest area after 7 years: 1407.10 sq km
# Forest area after 8 years: 1477.46 sq km
# Forest area after 9 years: 1551.33 sq km
# Forest area after 10 years: 1628.89 sq km
# Forest area after 11 years: 1710.34 sq km
# Forest area after 12 years: 1795.86 sq km
# Forest area after 13 years: 1885.65 sq km
# Forest area after 14 years: 1979.93 sq km
# Forest area after 15 years: 2078.93 sq km
# Forest area after 16 years: 2182.87 sq km
# Forest area after 17 years: 2292.02 sq km
# Forest area after 18 years: 2406.62 sq km
# Forest area after 19 years: 2526.95 sq km
# Forest area after 20 years: 2653.30 sq km
# Forest area after 21 years: 2785.96 sq km
# Forest area after 22 years: 2925.26 sq km
# Forest area after 23 years: 3071.52 sq km
# Forest area after 24 years: 3225.10 sq km
# Forest area after 25 years: 3386.35 sq km
# Forest area after 26 years: 3555.67 sq km
# Forest area after 27 years: 3733.46 sq km
# Forest area after 28 years: 3920.13 sq km
# Forest area after 29 years: 4116.14 sq km
# Forest area after 30 years: 4321.94 sq km
# Forest area after 31 years: 4538.04 sq km
# Forest area after 32 years: 4764.94 sq km
# Forest area after 33 years: 5003.19 sq km
